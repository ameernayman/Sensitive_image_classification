# %% [markdown]
# # Sensitive Data classification for text
# ## This model run in google colab https://colab.research.google.com/

# %%
import tensorflow as tf
import json
import os
import random
import numpy
import matplotlib.pyplot as plot
import matplotlib.image as matimage
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.image import ImageDataGenerator as imgData
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
image_folder = "/content/Sensitive_image_classification"
if os.path.exists(image_folder) != True:
  # !git clone https://github.com/ameernayman/Sensitive_image_classification.git

image_training = image_folder + "/dataset_images/image_training"
image_validation = image_folder + "/dataset_images/image_validation"
sensitive_training = os.path.join(image_training + "/image_sensitive")
nonsensitive_training = os.path.join(image_training + "/image_nonsensitive")
sensitive_validation = os.path.join(image_validation + "/image_sensitive")
nonsensitive_validation = os.path.join(image_validation + "/image_nonsensitive")
# Out:
# Cloning into 'Sensitive_image_classification'...
# remote: Enumerating objects: 741, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 741 (delta 7), reused 6 (delta 0), pack-reused 709
# Receiving objects: 100% (741/741), 94.48 MiB | 16.21 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %% [markdown]
# ## Training Sample Dataset

# %%
# %matplotlib inline



no_rows = 4
no_cols = 4
figure = plot.gcf()
figure.set_size_inches(no_cols * 4, no_rows * 4)

index = 0

list_training_sensitive = os.listdir(sensitive_training)
list_training_nonsensitive = os.listdir(nonsensitive_training)

index += 8
sens_images = [os.path.join(sensitive_training, fname) 
                for fname in list_training_sensitive[index-8:index]]
nonsens_images = [os.path.join(nonsensitive_training, fname) 
                for fname in list_training_nonsensitive[index-8:index]]

for val, path in enumerate(sens_images+nonsens_images):
  sub_pot = plot.subplot(no_rows, no_cols, val + 1)
  sub_pot.axis('Off')

  image = matimage.imread(path)
  plot.imshow(image)

plot.show()

# %% [markdown]
# ## CallBack function

# %%
no_epochs = 500
ACCURACY = 0.99
class myEpoch(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if logs.get('acc') > ACCURACY:
      print(" Accurracy is 0.99 then cancel the epoch")
      self.model.stop_training = True

epoch_callbacks = myEpoch()

# %% [markdown]
# ## Model

# %%
image_model = tf.keras.models.Sequential([
 
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),

  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

image_model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['acc'])


image_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 512)               6423040
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 6,811,969
# Trainable params: 6,811,969
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Valdation and Training Dataset Augmentation and  model fitting,

# %%
dataset_train = imgData(rescale=1/255,
                                  rotation_range=20,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  fill_mode='nearest')
validation_datagen = imgData(rescale=1/255)

gen_training = dataset_train.flow_from_directory(
        image_training,
        target_size=(150, 150),
        batch_size=30,
        class_mode='binary',
        shuffle=True
       )

validation_generator = validation_datagen.flow_from_directory(
        image_validation,
        target_size=(150, 150),
        batch_size=5,
        class_mode='binary',
        shuffle=True
        )


data_his = image_model.fit(
      gen_training,
      steps_per_epoch=10,
      epochs=no_epochs,
      verbose=1,
      validation_data = validation_generator,
      validation_steps=8,
      callbacks=[epoch_callbacks])
# Out:
# Found 600 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Epoch 1/500
# 10/10 [==============================] - 27s 1s/step - loss: 0.7709 - acc: 0.5533 - val_loss: 0.6572 - val_acc: 0.5000
# Epoch 2/500
# 10/10 [==============================] - 7s 644ms/step - loss: 0.6289 - acc: 0.6500 - val_loss: 0.4761 - val_acc: 0.8500
# Epoch 3/500
# 10/10 [==============================] - 5s 564ms/step - loss: 0.5753 - acc: 0.7367 - val_loss: 0.4034 - val_acc: 0.8500
# Epoch 4/500
# 10/10 [==============================] - 4s 414ms/step - loss: 0.4678 - acc: 0.8100 - val_loss: 0.3804 - val_acc: 0.8000
# Epoch 5/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.5103 - acc: 0.7467 - val_loss: 0.3645 - val_acc: 0.8750
# Epoch 6/500
# 10/10 [==============================] - 4s 397ms/step - loss: 0.4861 - acc: 0.7500 - val_loss: 0.3667 - val_acc: 0.8000
# Epoch 7/500
# 10/10 [==============================] - 4s 390ms/step - loss: 0.4243 - acc: 0.7800 - val_loss: 0.3003 - val_acc: 0.9000
# Epoch 8/500
# 10/10 [==============================] - 4s 372ms/step - loss: 0.4004 - acc: 0.8100 - val_loss: 0.2758 - val_acc: 0.9000
# Epoch 9/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.4324 - acc: 0.8267 - val_loss: 0.2950 - val_acc: 0.8750
# Epoch 10/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.3994 - acc: 0.8133 - val_loss: 0.3728 - val_acc: 0.7750
# Epoch 11/500
# 10/10 [==============================] - 4s 380ms/step - loss: 0.4643 - acc: 0.7833 - val_loss: 0.2384 - val_acc: 0.9500
# Epoch 12/500
# 10/10 [==============================] - 4s 384ms/step - loss: 0.4773 - acc: 0.7767 - val_loss: 0.2624 - val_acc: 0.9500
# Epoch 13/500
# 10/10 [==============================] - 4s 390ms/step - loss: 0.3862 - acc: 0.8500 - val_loss: 0.1686 - val_acc: 0.9500
# Epoch 14/500
# 10/10 [==============================] - 4s 389ms/step - loss: 0.4054 - acc: 0.8200 - val_loss: 0.1984 - val_acc: 0.9750
# Epoch 15/500
# 10/10 [==============================] - 5s 528ms/step - loss: 0.3723 - acc: 0.8367 - val_loss: 0.2051 - val_acc: 0.9000
# Epoch 16/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.3927 - acc: 0.8533 - val_loss: 0.3147 - val_acc: 0.8500
# Epoch 17/500
# 10/10 [==============================] - 4s 372ms/step - loss: 0.4139 - acc: 0.7900 - val_loss: 0.2219 - val_acc: 0.9250
# Epoch 18/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.3771 - acc: 0.8333 - val_loss: 0.1653 - val_acc: 0.9500
# Epoch 19/500
# 10/10 [==============================] - 4s 363ms/step - loss: 0.3112 - acc: 0.8633 - val_loss: 0.1627 - val_acc: 0.9250
# Epoch 20/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.4133 - acc: 0.8467 - val_loss: 0.2118 - val_acc: 0.9750
# Epoch 21/500
# 10/10 [==============================] - 5s 503ms/step - loss: 0.3187 - acc: 0.8667 - val_loss: 0.1136 - val_acc: 0.9500
# Epoch 22/500
# 10/10 [==============================] - 4s 441ms/step - loss: 0.3629 - acc: 0.8533 - val_loss: 0.2475 - val_acc: 0.9000
# Epoch 23/500
# 10/10 [==============================] - 5s 520ms/step - loss: 0.3818 - acc: 0.8433 - val_loss: 0.2009 - val_acc: 0.9000
# Epoch 24/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.3400 - acc: 0.8400 - val_loss: 0.1245 - val_acc: 0.9500
# Epoch 25/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.3183 - acc: 0.8733 - val_loss: 0.1624 - val_acc: 0.9500
# Epoch 26/500
# 10/10 [==============================] - 7s 733ms/step - loss: 0.3126 - acc: 0.8667 - val_loss: 0.1743 - val_acc: 0.9500
# Epoch 27/500
# 10/10 [==============================] - 7s 599ms/step - loss: 0.3469 - acc: 0.8367 - val_loss: 0.1081 - val_acc: 0.9750
# Epoch 28/500
# 10/10 [==============================] - 5s 486ms/step - loss: 0.2882 - acc: 0.8967 - val_loss: 0.2166 - val_acc: 0.9000
# Epoch 29/500
# 10/10 [==============================] - 6s 621ms/step - loss: 0.2831 - acc: 0.8767 - val_loss: 0.0372 - val_acc: 1.0000
# Epoch 30/500
# 10/10 [==============================] - 5s 495ms/step - loss: 0.3488 - acc: 0.8600 - val_loss: 0.1289 - val_acc: 1.0000
# Epoch 31/500
# 10/10 [==============================] - 5s 439ms/step - loss: 0.3099 - acc: 0.8733 - val_loss: 0.1256 - val_acc: 0.9250
# Epoch 32/500
# 10/10 [==============================] - 5s 511ms/step - loss: 0.2566 - acc: 0.9000 - val_loss: 0.1529 - val_acc: 0.9500
# Epoch 33/500
# 10/10 [==============================] - 4s 391ms/step - loss: 0.2444 - acc: 0.9000 - val_loss: 0.1021 - val_acc: 0.9500
# Epoch 34/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.2849 - acc: 0.8667 - val_loss: 0.2114 - val_acc: 0.9250
# Epoch 35/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.2749 - acc: 0.8900 - val_loss: 0.0896 - val_acc: 0.9750
# Epoch 36/500
# 10/10 [==============================] - 5s 532ms/step - loss: 0.2086 - acc: 0.9200 - val_loss: 0.1864 - val_acc: 0.9250
# Epoch 37/500
# 10/10 [==============================] - 4s 391ms/step - loss: 0.2994 - acc: 0.8667 - val_loss: 0.1887 - val_acc: 0.9000
# Epoch 38/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.2549 - acc: 0.9033 - val_loss: 0.1062 - val_acc: 0.9500
# Epoch 39/500
# 10/10 [==============================] - 4s 359ms/step - loss: 0.2458 - acc: 0.9033 - val_loss: 0.1507 - val_acc: 0.9500
# Epoch 40/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.2584 - acc: 0.9067 - val_loss: 0.1012 - val_acc: 0.9500
# Epoch 41/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.2498 - acc: 0.8967 - val_loss: 0.0794 - val_acc: 0.9750
# Epoch 42/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.2460 - acc: 0.8967 - val_loss: 0.1532 - val_acc: 0.9000
# Epoch 43/500
# 10/10 [==============================] - 5s 501ms/step - loss: 0.1993 - acc: 0.9067 - val_loss: 0.1441 - val_acc: 0.9000
# Epoch 44/500
# 10/10 [==============================] - 4s 427ms/step - loss: 0.3629 - acc: 0.8467 - val_loss: 0.1380 - val_acc: 0.9500
# Epoch 45/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.3298 - acc: 0.8533 - val_loss: 0.1669 - val_acc: 0.9500
# Epoch 46/500
# 10/10 [==============================] - 4s 370ms/step - loss: 0.3084 - acc: 0.8833 - val_loss: 0.1052 - val_acc: 0.9750
# Epoch 47/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.2361 - acc: 0.9133 - val_loss: 0.1173 - val_acc: 0.9750
# Epoch 48/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.2795 - acc: 0.9167 - val_loss: 0.0521 - val_acc: 0.9750
# Epoch 49/500
# 10/10 [==============================] - 4s 388ms/step - loss: 0.2441 - acc: 0.9000 - val_loss: 0.1139 - val_acc: 0.9500
# Epoch 50/500
# 10/10 [==============================] - 4s 384ms/step - loss: 0.2118 - acc: 0.9267 - val_loss: 0.0291 - val_acc: 1.0000
# Epoch 51/500
# 10/10 [==============================] - 4s 437ms/step - loss: 0.2299 - acc: 0.9067 - val_loss: 0.0607 - val_acc: 1.0000
# Epoch 52/500
# 10/10 [==============================] - 4s 393ms/step - loss: 0.2317 - acc: 0.9100 - val_loss: 0.2370 - val_acc: 0.9250
# Epoch 53/500
# 10/10 [==============================] - 4s 401ms/step - loss: 0.1819 - acc: 0.9267 - val_loss: 0.1055 - val_acc: 0.9500
# Epoch 54/500
# 10/10 [==============================] - 4s 402ms/step - loss: 0.1874 - acc: 0.9400 - val_loss: 0.1889 - val_acc: 0.9500
# Epoch 55/500
# 10/10 [==============================] - 4s 372ms/step - loss: 0.2013 - acc: 0.9333 - val_loss: 0.0695 - val_acc: 1.0000
# Epoch 56/500
# 10/10 [==============================] - 4s 372ms/step - loss: 0.1706 - acc: 0.9400 - val_loss: 0.0317 - val_acc: 1.0000
# Epoch 57/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.1491 - acc: 0.9333 - val_loss: 0.2799 - val_acc: 0.9000
# Epoch 58/500
# 10/10 [==============================] - 4s 406ms/step - loss: 0.1956 - acc: 0.9267 - val_loss: 0.0689 - val_acc: 1.0000
# Epoch 59/500
# 10/10 [==============================] - 4s 364ms/step - loss: 0.1490 - acc: 0.9533 - val_loss: 0.0925 - val_acc: 0.9500
# Epoch 60/500
# 10/10 [==============================] - 4s 428ms/step - loss: 0.2179 - acc: 0.9300 - val_loss: 0.0164 - val_acc: 1.0000
# Epoch 61/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.2481 - acc: 0.9000 - val_loss: 0.1071 - val_acc: 0.9500
# Epoch 62/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.2251 - acc: 0.9067 - val_loss: 0.2515 - val_acc: 0.9500
# Epoch 63/500
# 10/10 [==============================] - 4s 368ms/step - loss: 0.2449 - acc: 0.9000 - val_loss: 0.0773 - val_acc: 0.9750
# Epoch 64/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.1673 - acc: 0.9333 - val_loss: 0.0728 - val_acc: 0.9750
# Epoch 65/500
# 10/10 [==============================] - 4s 399ms/step - loss: 0.1672 - acc: 0.9300 - val_loss: 0.0349 - val_acc: 1.0000
# Epoch 66/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.1611 - acc: 0.9300 - val_loss: 0.0751 - val_acc: 0.9750
# Epoch 67/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.1295 - acc: 0.9400 - val_loss: 0.0660 - val_acc: 0.9750
# Epoch 68/500
# 10/10 [==============================] - 4s 370ms/step - loss: 0.1461 - acc: 0.9600 - val_loss: 0.0373 - val_acc: 0.9750
# Epoch 69/500
# 10/10 [==============================] - 4s 372ms/step - loss: 0.2071 - acc: 0.9200 - val_loss: 0.1886 - val_acc: 0.9250
# Epoch 70/500
# 10/10 [==============================] - 4s 370ms/step - loss: 0.2441 - acc: 0.9100 - val_loss: 0.1218 - val_acc: 0.9750
# Epoch 71/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.2185 - acc: 0.9167 - val_loss: 0.1618 - val_acc: 0.9000
# Epoch 72/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.1186 - acc: 0.9600 - val_loss: 0.2632 - val_acc: 0.8750
# Epoch 73/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.1439 - acc: 0.9333 - val_loss: 0.1149 - val_acc: 0.9500
# Epoch 74/500
# 10/10 [==============================] - 4s 391ms/step - loss: 0.1598 - acc: 0.9467 - val_loss: 0.0712 - val_acc: 0.9500
# Epoch 75/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.2114 - acc: 0.9300 - val_loss: 0.1997 - val_acc: 0.8500
# Epoch 76/500
# 10/10 [==============================] - 4s 401ms/step - loss: 0.1790 - acc: 0.9433 - val_loss: 0.3030 - val_acc: 0.8750
# Epoch 77/500
# 10/10 [==============================] - 5s 435ms/step - loss: 0.1469 - acc: 0.9500 - val_loss: 0.1583 - val_acc: 0.9500
# Epoch 78/500
# 10/10 [==============================] - 4s 389ms/step - loss: 0.1523 - acc: 0.9400 - val_loss: 0.0559 - val_acc: 0.9750
# Epoch 79/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.1290 - acc: 0.9500 - val_loss: 0.1616 - val_acc: 0.9000
# Epoch 80/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.1236 - acc: 0.9567 - val_loss: 0.1976 - val_acc: 0.9000
# Epoch 81/500
# 10/10 [==============================] - 4s 388ms/step - loss: 0.1044 - acc: 0.9633 - val_loss: 0.1570 - val_acc: 0.9500
# Epoch 82/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.1373 - acc: 0.9433 - val_loss: 0.0724 - val_acc: 0.9500
# Epoch 83/500
# 10/10 [==============================] - 4s 397ms/step - loss: 0.1372 - acc: 0.9600 - val_loss: 0.1221 - val_acc: 0.9250
# Epoch 84/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.1270 - acc: 0.9600 - val_loss: 0.1193 - val_acc: 0.9250
# Epoch 85/500
# 10/10 [==============================] - 4s 395ms/step - loss: 0.1724 - acc: 0.9400 - val_loss: 0.1294 - val_acc: 0.9500
# Epoch 86/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.1272 - acc: 0.9367 - val_loss: 0.1335 - val_acc: 0.9750
# Epoch 87/500
# 10/10 [==============================] - 4s 369ms/step - loss: 0.1211 - acc: 0.9600 - val_loss: 0.0861 - val_acc: 0.9750
# Epoch 88/500
# 10/10 [==============================] - 4s 390ms/step - loss: 0.1276 - acc: 0.9467 - val_loss: 0.0646 - val_acc: 0.9750
# Epoch 89/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.1596 - acc: 0.9333 - val_loss: 0.1034 - val_acc: 0.9750
# Epoch 90/500
# 10/10 [==============================] - 4s 380ms/step - loss: 0.0670 - acc: 0.9800 - val_loss: 0.0965 - val_acc: 0.9750
# Epoch 91/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.1324 - acc: 0.9533 - val_loss: 0.1174 - val_acc: 0.9500
# Epoch 92/500
# 10/10 [==============================] - 4s 403ms/step - loss: 0.1343 - acc: 0.9467 - val_loss: 0.0698 - val_acc: 0.9500
# Epoch 93/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.1189 - acc: 0.9633 - val_loss: 0.1008 - val_acc: 0.9750
# Epoch 94/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.1263 - acc: 0.9467 - val_loss: 0.0739 - val_acc: 0.9750
# Epoch 95/500
# 10/10 [==============================] - 4s 369ms/step - loss: 0.1291 - acc: 0.9567 - val_loss: 0.0926 - val_acc: 0.9750
# Epoch 96/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.2309 - acc: 0.9133 - val_loss: 0.0565 - val_acc: 0.9750
# Epoch 97/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.1880 - acc: 0.9400 - val_loss: 0.1409 - val_acc: 0.9250
# Epoch 98/500
# 10/10 [==============================] - 4s 395ms/step - loss: 0.1509 - acc: 0.9400 - val_loss: 0.0624 - val_acc: 0.9750
# Epoch 99/500
# 10/10 [==============================] - 4s 366ms/step - loss: 0.1247 - acc: 0.9533 - val_loss: 0.0238 - val_acc: 1.0000
# Epoch 100/500
# 10/10 [==============================] - 5s 530ms/step - loss: 0.1537 - acc: 0.9433 - val_loss: 0.0688 - val_acc: 1.0000
# Epoch 101/500
# 10/10 [==============================] - 7s 789ms/step - loss: 0.1515 - acc: 0.9300 - val_loss: 0.0791 - val_acc: 1.0000
# Epoch 102/500
# 10/10 [==============================] - 7s 619ms/step - loss: 0.1311 - acc: 0.9400 - val_loss: 0.0278 - val_acc: 0.9750
# Epoch 103/500
# 10/10 [==============================] - 4s 455ms/step - loss: 0.1249 - acc: 0.9467 - val_loss: 0.0933 - val_acc: 0.9500
# Epoch 104/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.1359 - acc: 0.9367 - val_loss: 0.0473 - val_acc: 1.0000
# Epoch 105/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.1286 - acc: 0.9567 - val_loss: 0.0552 - val_acc: 0.9750
# Epoch 106/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.0835 - acc: 0.9667 - val_loss: 0.1392 - val_acc: 0.9750
# Epoch 107/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.1140 - acc: 0.9533 - val_loss: 0.0760 - val_acc: 0.9750
# Epoch 108/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.1203 - acc: 0.9567 - val_loss: 0.0139 - val_acc: 1.0000
# Epoch 109/500
# 10/10 [==============================] - 4s 370ms/step - loss: 0.1612 - acc: 0.9433 - val_loss: 0.1510 - val_acc: 0.9250
# Epoch 110/500
# 10/10 [==============================] - 5s 465ms/step - loss: 0.0989 - acc: 0.9667 - val_loss: 0.1573 - val_acc: 0.9500
# Epoch 111/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.1073 - acc: 0.9700 - val_loss: 0.2603 - val_acc: 0.9250
# Epoch 112/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.1275 - acc: 0.9500 - val_loss: 0.0817 - val_acc: 0.9750
# Epoch 113/500
# 10/10 [==============================] - 4s 380ms/step - loss: 0.1012 - acc: 0.9700 - val_loss: 0.0591 - val_acc: 1.0000
# Epoch 114/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0882 - acc: 0.9600 - val_loss: 0.0358 - val_acc: 0.9750
# Epoch 115/500
# 10/10 [==============================] - 4s 380ms/step - loss: 0.1178 - acc: 0.9433 - val_loss: 0.2262 - val_acc: 0.9250
# Epoch 116/500
# 10/10 [==============================] - 4s 394ms/step - loss: 0.1811 - acc: 0.9333 - val_loss: 0.3263 - val_acc: 0.8500
# Epoch 117/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.1423 - acc: 0.9467 - val_loss: 0.1243 - val_acc: 0.9250
# Epoch 118/500
# 10/10 [==============================] - 4s 369ms/step - loss: 0.1558 - acc: 0.9400 - val_loss: 0.0552 - val_acc: 0.9750
# Epoch 119/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.1016 - acc: 0.9667 - val_loss: 0.0792 - val_acc: 0.9750
# Epoch 120/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.0942 - acc: 0.9600 - val_loss: 0.0922 - val_acc: 0.9500
# Epoch 121/500
# 10/10 [==============================] - 4s 391ms/step - loss: 0.0950 - acc: 0.9733 - val_loss: 0.0498 - val_acc: 0.9750
# Epoch 122/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.0923 - acc: 0.9700 - val_loss: 0.0191 - val_acc: 1.0000
# Epoch 123/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.1107 - acc: 0.9467 - val_loss: 0.0457 - val_acc: 1.0000
# Epoch 124/500
# 10/10 [==============================] - 4s 370ms/step - loss: 0.0866 - acc: 0.9733 - val_loss: 0.1283 - val_acc: 0.9500
# Epoch 125/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0757 - acc: 0.9700 - val_loss: 0.0731 - val_acc: 0.9750
# Epoch 126/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.0729 - acc: 0.9767 - val_loss: 0.0687 - val_acc: 0.9750
# Epoch 127/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.1134 - acc: 0.9667 - val_loss: 0.1183 - val_acc: 0.9500
# Epoch 128/500
# 10/10 [==============================] - 4s 406ms/step - loss: 0.0945 - acc: 0.9667 - val_loss: 0.0627 - val_acc: 0.9750
# Epoch 129/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.1710 - acc: 0.9333 - val_loss: 0.0050 - val_acc: 1.0000
# Epoch 130/500
# 10/10 [==============================] - 4s 392ms/step - loss: 0.1297 - acc: 0.9600 - val_loss: 0.1837 - val_acc: 0.9250
# Epoch 131/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.0858 - acc: 0.9733 - val_loss: 0.1228 - val_acc: 0.9750
# Epoch 132/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.0976 - acc: 0.9667 - val_loss: 0.0136 - val_acc: 1.0000
# Epoch 133/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.1374 - acc: 0.9533 - val_loss: 0.1785 - val_acc: 0.9250
# Epoch 134/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0763 - acc: 0.9733 - val_loss: 0.2219 - val_acc: 0.9250
# Epoch 135/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.0772 - acc: 0.9700 - val_loss: 0.0451 - val_acc: 1.0000
# Epoch 136/500
# 10/10 [==============================] - 4s 379ms/step - loss: 0.0975 - acc: 0.9533 - val_loss: 0.0513 - val_acc: 0.9750
# Epoch 137/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.1630 - acc: 0.9333 - val_loss: 0.0778 - val_acc: 0.9500
# Epoch 138/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.2040 - acc: 0.9333 - val_loss: 0.1009 - val_acc: 0.9500
# Epoch 139/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.1365 - acc: 0.9500 - val_loss: 0.1304 - val_acc: 0.9250
# Epoch 140/500
# 10/10 [==============================] - 4s 392ms/step - loss: 0.1593 - acc: 0.9400 - val_loss: 0.0320 - val_acc: 0.9750
# Epoch 141/500
# 10/10 [==============================] - 4s 397ms/step - loss: 0.1058 - acc: 0.9767 - val_loss: 0.1309 - val_acc: 0.9500
# Epoch 142/500
# 10/10 [==============================] - 4s 363ms/step - loss: 0.0925 - acc: 0.9633 - val_loss: 0.0279 - val_acc: 1.0000
# Epoch 143/500
# 10/10 [==============================] - 4s 379ms/step - loss: 0.0734 - acc: 0.9800 - val_loss: 0.0687 - val_acc: 0.9750
# Epoch 144/500
# 10/10 [==============================] - 4s 394ms/step - loss: 0.0797 - acc: 0.9600 - val_loss: 0.0980 - val_acc: 0.9250
# Epoch 145/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.1065 - acc: 0.9633 - val_loss: 0.1432 - val_acc: 0.9500
# Epoch 146/500
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0845 - acc: 0.9633 - val_loss: 0.0315 - val_acc: 1.0000
# Epoch 147/500
# 10/10 [==============================] - 5s 477ms/step - loss: 0.0943 - acc: 0.9733 - val_loss: 0.0476 - val_acc: 0.9750
# Epoch 148/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.0484 - acc: 0.9833 - val_loss: 0.0529 - val_acc: 0.9500
# Epoch 149/500
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0646 - acc: 0.9767 - val_loss: 0.0411 - val_acc: 1.0000
# Epoch 150/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.0573 - acc: 0.9833 - val_loss: 0.1422 - val_acc: 0.9750
# Epoch 151/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0903 - acc: 0.9667 - val_loss: 0.0269 - val_acc: 0.9750
# Epoch 152/500
# 10/10 [==============================] - 4s 388ms/step - loss: 0.0672 - acc: 0.9800 - val_loss: 0.1752 - val_acc: 0.9500
# Epoch 153/500
# 10/10 [==============================] - 4s 354ms/step - loss: 0.0638 - acc: 0.9800 - val_loss: 0.0912 - val_acc: 0.9500
# Epoch 154/500
# 10/10 [==============================] - 4s 368ms/step - loss: 0.0581 - acc: 0.9800 - val_loss: 0.2289 - val_acc: 0.9500
# Epoch 155/500
# 10/10 [==============================] - 4s 389ms/step - loss: 0.0348 - acc: 0.9867 - val_loss: 0.2358 - val_acc: 0.9500
# Epoch 156/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0735 - acc: 0.9800 - val_loss: 0.0082 - val_acc: 1.0000
# Epoch 157/500
# 10/10 [==============================] - 4s 402ms/step - loss: 0.1367 - acc: 0.9500 - val_loss: 0.2981 - val_acc: 0.9250
# Epoch 158/500
# 10/10 [==============================] - 4s 399ms/step - loss: 0.0808 - acc: 0.9700 - val_loss: 0.0786 - val_acc: 0.9500
# Epoch 159/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.0703 - acc: 0.9667 - val_loss: 0.0661 - val_acc: 0.9750
# Epoch 160/500
# 10/10 [==============================] - 4s 354ms/step - loss: 0.0910 - acc: 0.9600 - val_loss: 0.1001 - val_acc: 0.9500
# Epoch 161/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.0558 - acc: 0.9767 - val_loss: 0.1552 - val_acc: 0.9500
# Epoch 162/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.0583 - acc: 0.9800 - val_loss: 0.0912 - val_acc: 0.9500
# Epoch 163/500
# 10/10 [==============================] - 4s 379ms/step - loss: 0.0629 - acc: 0.9800 - val_loss: 0.0632 - val_acc: 0.9500
# Epoch 164/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0513 - acc: 0.9900 Accurracy is 0.99 then cancel the epoch
# 10/10 [==============================] - 4s 381ms/step - loss: 0.0513 - acc: 0.9900 - val_loss: 0.0854 - val_acc: 0.9500

# %% [markdown]
# ## Plotting Accuracy and Loss graph for Image Model

# %%
def graphsPlot(data_his, str):
  plot.plot(data_his.history[str])
  plot.plot(data_his.history['val_'+str])
  plot.xlabel("Number_of_Epochs")
  plot.ylabel(str)
  plot.legend([str, 'val_'+str])
  plot.show()
  
graphsPlot(data_his, "acc")
graphsPlot(data_his, "loss")

# %% [markdown]
# ## Ploting the Confusion Matrix for Image model

# %%
import seaborn
image_predicted = image_model.predict(validation_generator,20)
predicted_image_labels = image_predicted > 0.5

length = numpy.size(predicted_image_labels)
predicted_image_labels = predicted_image_labels.reshape(length, )

for count in range (1, 5):
  value = count * length // 4
  image_mid = 49
  image_start = image_mid-((value+1)//2)+1
  image_end = image_mid+((value+1)//2)
  confusion_matrix = tf.math.confusion_matrix(labels=validation_generator.labels[image_start:image_end],predictions=predicted_image_labels[image_start:image_end])

  confusion_numpy = confusion_matrix.numpy()
  confidence_accuracy = (confusion_numpy[0, 0] + confusion_numpy[1, 1])/ numpy.sum(confusion_numpy) * 100
  print("Accuracy for", str(value), "Image Data = ", confidence_accuracy)

  plot.figure(figsize = (9,6))
  seaborn.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Blues')
  plot.title("Confusion Matrix for " + str(value) + " Image Data")
  plot.xlabel('Predicted')
  plot.ylabel('Expected')
# Out:
# Accuracy for 25 Image Data =  60.0
# Accuracy for 50 Image Data =  61.224489795918366
# Accuracy for 75 Image Data =  52.0
# Accuracy for 100 Image Data =  49.494949494949495

# %% [markdown]
# ## Experiment

# %%
from google.colab import files as f
from keras.preprocessing import image as img
file = f.upload()
dict_result = dict()

for fval in file.keys():
 
  source = '/content/' + fval
  img_arr=img.load_img(source, target_size=(150, 150))
  #img_arr = img.load_img(source, target_size=(150, 150))
  val = img.img_to_array(img_arr)
  val = numpy.expand_dims(val, axis=0)

  imgs = numpy.vstack([val])
  classification = image_model.predict(imgs, batch_size=10)
  if classification[0]>0.5:
    print(fval + " - Image is sensitive")
    dict_result[fval] = "Image is sensitive"
  else:
    print(fval + " - Image is nonsensitive")
    dict_result[fval] = "Image is nonsensitive"

plot.figure(figsize=(20,20))
   
for i, fn in enumerate(file.keys()):
  img = plot.imread(fn)  
  plot.subplot(5, 5, i+1)
  plot.axis("off")
  plot.imshow(image)
  ans = fn + ": " + dict_result[fn]
  plot.title(ans)
# Out:
#      <input type="file" id="files-34d083e8-b460-4097-a0a1-664b59d88388" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34d083e8-b460-4097-a0a1-664b59d88388">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving aircraft.jpg to aircraft (3).jpg
# Saving credit_card.png to credit_card.png
# aircraft.jpg - Image is nonsensitive
# credit_card.png - Image is sensitive
