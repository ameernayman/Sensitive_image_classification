# %% [markdown]
# # Sensitive Data classification for text
# ## This model run in google colab https://colab.research.google.com/

# %%
import tensorflow as tf
import json
import os
import random
import numpy
import matplotlib.pyplot as plot
import matplotlib.image as matimage
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.image import ImageDataGenerator as imgData
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
image_folder = "/content/Sensitive_image_classification"
if os.path.exists(image_folder) != True:
  # !git clone https://github.com/ameernayman/Sensitive_image_classification.git

image_training = image_folder + "/dataset_images/image_training"
image_validation = image_folder + "/dataset_images/image_validation"
sensitive_training = os.path.join(image_training + "/image_sensitive")
nonsensitive_training = os.path.join(image_training + "/image_nonsensitive")
sensitive_validation = os.path.join(image_validation + "/image_sensitive")
nonsensitive_validation = os.path.join(image_validation + "/image_nonsensitive")

# %% [markdown]
# ## Training Sample Dataset

# %%
# %matplotlib inline



no_rows = 4
no_cols = 4
figure = plot.gcf()
figure.set_size_inches(no_cols * 4, no_rows * 4)

index = 0

list_training_sensitive = os.listdir(sensitive_training)
list_training_nonsensitive = os.listdir(nonsensitive_training)

index += 8
sens_images = [os.path.join(sensitive_training, fname) 
                for fname in list_training_sensitive[index-8:index]]
nonsens_images = [os.path.join(nonsensitive_training, fname) 
                for fname in list_training_nonsensitive[index-8:index]]

for val, path in enumerate(sens_images+nonsens_images):
  sub_pot = plot.subplot(no_rows, no_cols, val + 1)
  sub_pot.axis('Off')

  image = matimage.imread(path)
  plot.imshow(image)

plot.show()

# %% [markdown]
# ## CallBack function

# %%
no_epochs = 500
ACCURACY = 0.99
class myEpoch(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if logs.get('acc') > ACCURACY:
      print(" Accurracy is 0.99 then cancel the epoch")
      self.model.stop_training = True

epoch_callbacks = myEpoch()

# %% [markdown]
# ## Model

# %%
image_model = tf.keras.models.Sequential([
 
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),

  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

image_model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['acc'])


image_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 512)               6423040
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 6,811,969
# Trainable params: 6,811,969
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Valdation and Training Dataset Augmentation and  model fitting,

# %%
dataset_train = imgData(rescale=1/255,
                                  rotation_range=20,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  fill_mode='nearest')
validation_datagen = imgData(rescale=1/255)

gen_training = dataset_train.flow_from_directory(
        image_training,
        target_size=(150, 150),
        batch_size=30,
        class_mode='binary',
        shuffle=True
       )

validation_generator = validation_datagen.flow_from_directory(
        image_validation,
        target_size=(150, 150),
        batch_size=5,
        class_mode='binary',
        shuffle=True
        )


data_his = image_model.fit(
      gen_training,
      steps_per_epoch=10,
      epochs=no_epochs,
      verbose=1,
      validation_data = validation_generator,
      validation_steps=8,
      callbacks=[epoch_callbacks])
# Out:
# Found 600 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Epoch 1/500
# 10/10 [==============================] - 4s 391ms/step - loss: 0.5317 - acc: 0.7567 - val_loss: 0.3982 - val_acc: 0.8000
# Epoch 2/500
# 10/10 [==============================] - 5s 515ms/step - loss: 0.5209 - acc: 0.7367 - val_loss: 0.2658 - val_acc: 0.9500
# Epoch 3/500
# 10/10 [==============================] - 4s 353ms/step - loss: 0.5094 - acc: 0.7600 - val_loss: 0.3684 - val_acc: 0.8750
# Epoch 4/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.4685 - acc: 0.7767 - val_loss: 0.4115 - val_acc: 0.8500
# Epoch 5/500
# 10/10 [==============================] - 85s 9s/step - loss: 0.4751 - acc: 0.8000 - val_loss: 0.3759 - val_acc: 0.8750
# Epoch 6/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.5299 - acc: 0.7567 - val_loss: 0.3394 - val_acc: 0.8500
# Epoch 7/500
# 10/10 [==============================] - 4s 427ms/step - loss: 0.5108 - acc: 0.7633 - val_loss: 0.3980 - val_acc: 0.8250
# Epoch 8/500
# 10/10 [==============================] - 5s 486ms/step - loss: 0.4829 - acc: 0.7833 - val_loss: 0.3271 - val_acc: 0.8500
# Epoch 9/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.4625 - acc: 0.7800 - val_loss: 0.4086 - val_acc: 0.8500
# Epoch 10/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.4647 - acc: 0.7967 - val_loss: 0.3488 - val_acc: 0.8750
# Epoch 11/500
# 10/10 [==============================] - 4s 384ms/step - loss: 0.4874 - acc: 0.7500 - val_loss: 0.2943 - val_acc: 0.9000
# Epoch 12/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.4367 - acc: 0.8200 - val_loss: 0.2917 - val_acc: 0.9000
# Epoch 13/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.4208 - acc: 0.8267 - val_loss: 0.2105 - val_acc: 0.9500
# Epoch 14/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.4117 - acc: 0.8133 - val_loss: 0.2581 - val_acc: 0.9750
# Epoch 15/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.4279 - acc: 0.8133 - val_loss: 0.3178 - val_acc: 0.8500
# Epoch 16/500
# 10/10 [==============================] - 4s 384ms/step - loss: 0.4237 - acc: 0.8033 - val_loss: 0.1900 - val_acc: 0.9750
# Epoch 17/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.4158 - acc: 0.8333 - val_loss: 0.2319 - val_acc: 0.9000
# Epoch 18/500
# 10/10 [==============================] - 4s 364ms/step - loss: 0.3223 - acc: 0.8733 - val_loss: 0.3698 - val_acc: 0.9000
# Epoch 19/500
# 10/10 [==============================] - 4s 384ms/step - loss: 0.4049 - acc: 0.8133 - val_loss: 0.2450 - val_acc: 0.9250
# Epoch 20/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.4724 - acc: 0.7733 - val_loss: 0.2794 - val_acc: 0.9000
# Epoch 21/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.3780 - acc: 0.8267 - val_loss: 0.2659 - val_acc: 0.8500
# Epoch 22/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.3771 - acc: 0.8533 - val_loss: 0.2621 - val_acc: 0.9000
# Epoch 23/500
# 10/10 [==============================] - 5s 451ms/step - loss: 0.3604 - acc: 0.8733 - val_loss: 0.3314 - val_acc: 0.8000
# Epoch 24/500
# 10/10 [==============================] - 4s 366ms/step - loss: 0.3977 - acc: 0.8300 - val_loss: 0.1956 - val_acc: 0.9750
# Epoch 25/500
# 10/10 [==============================] - 4s 388ms/step - loss: 0.3763 - acc: 0.8200 - val_loss: 0.2838 - val_acc: 0.8750
# Epoch 26/500
# 10/10 [==============================] - 4s 372ms/step - loss: 0.3456 - acc: 0.8533 - val_loss: 0.2709 - val_acc: 0.9000
# Epoch 27/500
# 10/10 [==============================] - 4s 359ms/step - loss: 0.3698 - acc: 0.8400 - val_loss: 0.2037 - val_acc: 0.9500
# Epoch 28/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.3580 - acc: 0.8467 - val_loss: 0.1432 - val_acc: 0.9000
# Epoch 29/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.2792 - acc: 0.9000 - val_loss: 0.1193 - val_acc: 0.9750
# Epoch 30/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.3434 - acc: 0.8433 - val_loss: 0.1536 - val_acc: 0.9250
# Epoch 31/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.2788 - acc: 0.8800 - val_loss: 0.0927 - val_acc: 1.0000
# Epoch 32/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.3493 - acc: 0.8433 - val_loss: 0.1278 - val_acc: 0.9500
# Epoch 33/500
# 10/10 [==============================] - 4s 367ms/step - loss: 0.3359 - acc: 0.8567 - val_loss: 0.1282 - val_acc: 0.9750
# Epoch 34/500
# 10/10 [==============================] - 4s 389ms/step - loss: 0.3289 - acc: 0.8700 - val_loss: 0.1777 - val_acc: 0.9250
# Epoch 35/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.3198 - acc: 0.8533 - val_loss: 0.5140 - val_acc: 0.7000
# Epoch 36/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.3374 - acc: 0.8533 - val_loss: 0.0967 - val_acc: 0.9750
# Epoch 37/500
# 10/10 [==============================] - 4s 392ms/step - loss: 0.3157 - acc: 0.8700 - val_loss: 0.2428 - val_acc: 0.9250
# Epoch 38/500
# 10/10 [==============================] - 5s 486ms/step - loss: 0.3058 - acc: 0.8533 - val_loss: 0.2618 - val_acc: 0.8500
# Epoch 39/500
# 10/10 [==============================] - 4s 403ms/step - loss: 0.2637 - acc: 0.8933 - val_loss: 0.0965 - val_acc: 0.9750
# Epoch 40/500
# 10/10 [==============================] - 4s 397ms/step - loss: 0.2165 - acc: 0.9067 - val_loss: 0.0935 - val_acc: 0.9750
# Epoch 41/500
# 10/10 [==============================] - 4s 367ms/step - loss: 0.2614 - acc: 0.9000 - val_loss: 0.0663 - val_acc: 1.0000
# Epoch 42/500
# 10/10 [==============================] - 4s 398ms/step - loss: 0.1887 - acc: 0.9333 - val_loss: 0.1206 - val_acc: 0.9500
# Epoch 43/500
# 10/10 [==============================] - 4s 380ms/step - loss: 0.4409 - acc: 0.8267 - val_loss: 0.2109 - val_acc: 0.9500
# Epoch 44/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.2971 - acc: 0.8967 - val_loss: 0.0443 - val_acc: 1.0000
# Epoch 45/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.2484 - acc: 0.8967 - val_loss: 0.1057 - val_acc: 0.9500
# Epoch 46/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.2546 - acc: 0.8667 - val_loss: 0.0934 - val_acc: 0.9750
# Epoch 47/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.1946 - acc: 0.9233 - val_loss: 0.0711 - val_acc: 0.9750
# Epoch 48/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.2161 - acc: 0.9000 - val_loss: 0.0322 - val_acc: 1.0000
# Epoch 49/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.2840 - acc: 0.8633 - val_loss: 0.0764 - val_acc: 0.9750
# Epoch 50/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.1825 - acc: 0.9300 - val_loss: 0.0625 - val_acc: 1.0000
# Epoch 51/500
# 10/10 [==============================] - 4s 364ms/step - loss: 0.1972 - acc: 0.9200 - val_loss: 0.0381 - val_acc: 1.0000
# Epoch 52/500
# 10/10 [==============================] - 4s 367ms/step - loss: 0.1793 - acc: 0.9467 - val_loss: 0.0901 - val_acc: 0.9750
# Epoch 53/500
# 10/10 [==============================] - 5s 478ms/step - loss: 0.1860 - acc: 0.9333 - val_loss: 0.0637 - val_acc: 0.9750
# Epoch 54/500
# 10/10 [==============================] - 4s 364ms/step - loss: 0.2101 - acc: 0.9200 - val_loss: 0.1360 - val_acc: 0.9250
# Epoch 55/500
# 10/10 [==============================] - 4s 369ms/step - loss: 0.1952 - acc: 0.9133 - val_loss: 0.1141 - val_acc: 0.9750
# Epoch 56/500
# 10/10 [==============================] - 4s 392ms/step - loss: 0.2919 - acc: 0.8667 - val_loss: 0.0843 - val_acc: 0.9750
# Epoch 57/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.2024 - acc: 0.9233 - val_loss: 0.0292 - val_acc: 1.0000
# Epoch 58/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.2859 - acc: 0.8767 - val_loss: 0.0596 - val_acc: 1.0000
# Epoch 59/500
# 10/10 [==============================] - 4s 370ms/step - loss: 0.2748 - acc: 0.8733 - val_loss: 0.0436 - val_acc: 1.0000
# Epoch 60/500
# 10/10 [==============================] - 4s 396ms/step - loss: 0.1980 - acc: 0.9233 - val_loss: 0.1557 - val_acc: 0.9250
# Epoch 61/500
# 10/10 [==============================] - 4s 399ms/step - loss: 0.1745 - acc: 0.9333 - val_loss: 0.1535 - val_acc: 0.9750
# Epoch 62/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.2235 - acc: 0.9233 - val_loss: 0.1089 - val_acc: 0.9500
# Epoch 63/500
# 10/10 [==============================] - 4s 439ms/step - loss: 0.2159 - acc: 0.9100 - val_loss: 0.1162 - val_acc: 0.9750
# Epoch 64/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.1860 - acc: 0.9233 - val_loss: 0.0981 - val_acc: 0.9750
# Epoch 65/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.1906 - acc: 0.9233 - val_loss: 0.0859 - val_acc: 0.9750
# Epoch 66/500
# 10/10 [==============================] - 4s 380ms/step - loss: 0.1550 - acc: 0.9500 - val_loss: 0.0681 - val_acc: 0.9500
# Epoch 67/500
# 10/10 [==============================] - 5s 486ms/step - loss: 0.1874 - acc: 0.9400 - val_loss: 0.0613 - val_acc: 0.9750
# Epoch 68/500
# 10/10 [==============================] - 4s 357ms/step - loss: 0.2028 - acc: 0.9000 - val_loss: 0.0269 - val_acc: 1.0000
# Epoch 69/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.1664 - acc: 0.9400 - val_loss: 0.1838 - val_acc: 0.9250
# Epoch 70/500
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1563 - acc: 0.9300 - val_loss: 0.0276 - val_acc: 1.0000
# Epoch 71/500
# 10/10 [==============================] - 4s 388ms/step - loss: 0.1595 - acc: 0.9333 - val_loss: 0.1006 - val_acc: 0.9750
# Epoch 72/500
# 10/10 [==============================] - 4s 358ms/step - loss: 0.1573 - acc: 0.9367 - val_loss: 0.1089 - val_acc: 0.9500
# Epoch 73/500
# 10/10 [==============================] - 4s 391ms/step - loss: 0.1987 - acc: 0.9200 - val_loss: 0.0550 - val_acc: 1.0000
# Epoch 74/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.1204 - acc: 0.9633 - val_loss: 0.0562 - val_acc: 0.9500
# Epoch 75/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.1493 - acc: 0.9333 - val_loss: 0.0539 - val_acc: 0.9750
# Epoch 76/500
# 10/10 [==============================] - 4s 367ms/step - loss: 0.2106 - acc: 0.9300 - val_loss: 0.0854 - val_acc: 0.9250
# Epoch 77/500
# 10/10 [==============================] - 5s 516ms/step - loss: 0.1526 - acc: 0.9400 - val_loss: 0.0472 - val_acc: 1.0000
# Epoch 78/500
# 10/10 [==============================] - 6s 675ms/step - loss: 0.1532 - acc: 0.9367 - val_loss: 0.0374 - val_acc: 0.9750
# Epoch 79/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.1417 - acc: 0.9500 - val_loss: 0.0452 - val_acc: 0.9750
# Epoch 80/500
# 10/10 [==============================] - 4s 464ms/step - loss: 0.1754 - acc: 0.9300 - val_loss: 0.0644 - val_acc: 0.9750
# Epoch 81/500
# 10/10 [==============================] - 4s 393ms/step - loss: 0.1729 - acc: 0.9200 - val_loss: 0.1536 - val_acc: 0.9250
# Epoch 82/500
# 10/10 [==============================] - 5s 489ms/step - loss: 0.1522 - acc: 0.9433 - val_loss: 0.1505 - val_acc: 0.9250
# Epoch 83/500
# 10/10 [==============================] - 6s 604ms/step - loss: 0.1576 - acc: 0.9467 - val_loss: 0.3432 - val_acc: 0.8500
# Epoch 84/500
# 10/10 [==============================] - 6s 631ms/step - loss: 0.2363 - acc: 0.9200 - val_loss: 0.1259 - val_acc: 0.9250
# Epoch 85/500
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1552 - acc: 0.9467 - val_loss: 0.0673 - val_acc: 0.9500
# Epoch 86/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.1981 - acc: 0.9200 - val_loss: 0.2057 - val_acc: 0.9000
# Epoch 87/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.1421 - acc: 0.9467 - val_loss: 0.1204 - val_acc: 0.9500
# Epoch 88/500
# 10/10 [==============================] - 4s 398ms/step - loss: 0.1384 - acc: 0.9600 - val_loss: 0.0503 - val_acc: 0.9750
# Epoch 89/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.1473 - acc: 0.9400 - val_loss: 0.0125 - val_acc: 1.0000
# Epoch 90/500
# 10/10 [==============================] - 4s 393ms/step - loss: 0.1142 - acc: 0.9667 - val_loss: 0.0798 - val_acc: 0.9750
# Epoch 91/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.1190 - acc: 0.9467 - val_loss: 0.0977 - val_acc: 0.9750
# Epoch 92/500
# 10/10 [==============================] - 4s 362ms/step - loss: 0.0969 - acc: 0.9667 - val_loss: 0.0081 - val_acc: 1.0000
# Epoch 93/500
# 10/10 [==============================] - 4s 389ms/step - loss: 0.1179 - acc: 0.9500 - val_loss: 0.0254 - val_acc: 0.9750
# Epoch 94/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.1689 - acc: 0.9333 - val_loss: 0.1973 - val_acc: 0.9250
# Epoch 95/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.1398 - acc: 0.9600 - val_loss: 0.1614 - val_acc: 0.9000
# Epoch 96/500
# 10/10 [==============================] - 4s 379ms/step - loss: 0.1345 - acc: 0.9500 - val_loss: 0.0873 - val_acc: 0.9250
# Epoch 97/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.1387 - acc: 0.9533 - val_loss: 0.0487 - val_acc: 0.9750
# Epoch 98/500
# 10/10 [==============================] - 4s 367ms/step - loss: 0.1178 - acc: 0.9633 - val_loss: 0.1740 - val_acc: 0.9250
# Epoch 99/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.1272 - acc: 0.9667 - val_loss: 0.2667 - val_acc: 0.8500
# Epoch 100/500
# 10/10 [==============================] - 4s 369ms/step - loss: 0.1737 - acc: 0.9333 - val_loss: 0.1550 - val_acc: 0.9500
# Epoch 101/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.1477 - acc: 0.9400 - val_loss: 0.1151 - val_acc: 0.9500
# Epoch 102/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.1097 - acc: 0.9633 - val_loss: 0.0801 - val_acc: 0.9750
# Epoch 103/500
# 10/10 [==============================] - 5s 443ms/step - loss: 0.1395 - acc: 0.9467 - val_loss: 0.0608 - val_acc: 0.9500
# Epoch 104/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0925 - acc: 0.9733 - val_loss: 0.0233 - val_acc: 1.0000
# Epoch 105/500
# 10/10 [==============================] - 4s 361ms/step - loss: 0.1296 - acc: 0.9533 - val_loss: 0.1813 - val_acc: 0.9500
# Epoch 106/500
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0945 - acc: 0.9700 - val_loss: 0.1698 - val_acc: 0.9750
# Epoch 107/500
# 10/10 [==============================] - 5s 513ms/step - loss: 0.2334 - acc: 0.9200 - val_loss: 0.0024 - val_acc: 1.0000
# Epoch 108/500
# 10/10 [==============================] - 8s 813ms/step - loss: 0.2169 - acc: 0.9200 - val_loss: 0.0796 - val_acc: 0.9750
# Epoch 109/500
# 10/10 [==============================] - 5s 449ms/step - loss: 0.1320 - acc: 0.9533 - val_loss: 0.0534 - val_acc: 0.9750
# Epoch 110/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.1223 - acc: 0.9467 - val_loss: 0.0153 - val_acc: 1.0000
# Epoch 111/500
# 10/10 [==============================] - 4s 355ms/step - loss: 0.1269 - acc: 0.9467 - val_loss: 0.0782 - val_acc: 0.9750
# Epoch 112/500
# 10/10 [==============================] - 4s 401ms/step - loss: 0.1489 - acc: 0.9433 - val_loss: 0.1358 - val_acc: 0.9000
# Epoch 113/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.1301 - acc: 0.9567 - val_loss: 0.2202 - val_acc: 0.8750
# Epoch 114/500
# 10/10 [==============================] - 4s 379ms/step - loss: 0.1552 - acc: 0.9267 - val_loss: 0.0633 - val_acc: 0.9750
# Epoch 115/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0911 - acc: 0.9733 - val_loss: 0.0785 - val_acc: 0.9500
# Epoch 116/500
# 10/10 [==============================] - 4s 392ms/step - loss: 0.0991 - acc: 0.9567 - val_loss: 0.0965 - val_acc: 0.9500
# Epoch 117/500
# 10/10 [==============================] - 5s 529ms/step - loss: 0.1110 - acc: 0.9667 - val_loss: 0.0643 - val_acc: 0.9750
# Epoch 118/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.1042 - acc: 0.9667 - val_loss: 0.1234 - val_acc: 0.9250
# Epoch 119/500
# 10/10 [==============================] - 5s 539ms/step - loss: 0.1421 - acc: 0.9433 - val_loss: 0.1044 - val_acc: 0.9500
# Epoch 120/500
# 10/10 [==============================] - 6s 561ms/step - loss: 0.0813 - acc: 0.9733 - val_loss: 0.1148 - val_acc: 0.9500
# Epoch 121/500
# 10/10 [==============================] - 5s 535ms/step - loss: 0.1204 - acc: 0.9500 - val_loss: 0.0514 - val_acc: 0.9750
# Epoch 122/500
# 10/10 [==============================] - 5s 462ms/step - loss: 0.0762 - acc: 0.9700 - val_loss: 0.1296 - val_acc: 0.9250
# Epoch 123/500
# 10/10 [==============================] - 4s 392ms/step - loss: 0.1274 - acc: 0.9567 - val_loss: 0.0988 - val_acc: 0.9500
# Epoch 124/500
# 10/10 [==============================] - 4s 369ms/step - loss: 0.1180 - acc: 0.9567 - val_loss: 0.1012 - val_acc: 0.9750
# Epoch 125/500
# 10/10 [==============================] - 5s 464ms/step - loss: 0.1135 - acc: 0.9633 - val_loss: 0.0110 - val_acc: 1.0000
# Epoch 126/500
# 10/10 [==============================] - 5s 510ms/step - loss: 0.1350 - acc: 0.9533 - val_loss: 0.0903 - val_acc: 0.9500
# Epoch 127/500
# 10/10 [==============================] - 4s 379ms/step - loss: 0.1085 - acc: 0.9500 - val_loss: 0.1598 - val_acc: 0.9500
# Epoch 128/500
# 10/10 [==============================] - 4s 368ms/step - loss: 0.0763 - acc: 0.9633 - val_loss: 0.0875 - val_acc: 0.9750
# Epoch 129/500
# 10/10 [==============================] - 6s 604ms/step - loss: 0.1063 - acc: 0.9667 - val_loss: 0.0180 - val_acc: 1.0000
# Epoch 130/500
# 10/10 [==============================] - 4s 407ms/step - loss: 0.0919 - acc: 0.9633 - val_loss: 0.0590 - val_acc: 0.9750
# Epoch 131/500
# 10/10 [==============================] - 5s 504ms/step - loss: 0.0773 - acc: 0.9667 - val_loss: 0.0313 - val_acc: 1.0000
# Epoch 132/500
# 10/10 [==============================] - 6s 603ms/step - loss: 0.0753 - acc: 0.9700 - val_loss: 0.0202 - val_acc: 1.0000
# Epoch 133/500
# 10/10 [==============================] - 6s 619ms/step - loss: 0.1151 - acc: 0.9567 - val_loss: 0.0158 - val_acc: 1.0000
# Epoch 134/500
# 10/10 [==============================] - 5s 549ms/step - loss: 0.1085 - acc: 0.9500 - val_loss: 0.0304 - val_acc: 1.0000
# Epoch 135/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.1497 - acc: 0.9433 - val_loss: 0.1521 - val_acc: 0.9750
# Epoch 136/500
# 10/10 [==============================] - 6s 568ms/step - loss: 0.1219 - acc: 0.9433 - val_loss: 0.1071 - val_acc: 0.9500
# Epoch 137/500
# 10/10 [==============================] - 5s 563ms/step - loss: 0.1331 - acc: 0.9633 - val_loss: 0.1150 - val_acc: 0.9750
# Epoch 138/500
# 10/10 [==============================] - 5s 470ms/step - loss: 0.1342 - acc: 0.9467 - val_loss: 0.0476 - val_acc: 1.0000
# Epoch 139/500
# 10/10 [==============================] - 4s 419ms/step - loss: 0.0999 - acc: 0.9667 - val_loss: 0.0306 - val_acc: 1.0000
# Epoch 140/500
# 10/10 [==============================] - 7s 693ms/step - loss: 0.0908 - acc: 0.9767 - val_loss: 0.1148 - val_acc: 0.9500
# Epoch 141/500
# 10/10 [==============================] - 7s 612ms/step - loss: 0.0645 - acc: 0.9833 - val_loss: 0.0401 - val_acc: 1.0000
# Epoch 142/500
# 10/10 [==============================] - 4s 414ms/step - loss: 0.0579 - acc: 0.9800 - val_loss: 0.0470 - val_acc: 0.9750
# Epoch 143/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.0742 - acc: 0.9800 - val_loss: 0.0197 - val_acc: 1.0000
# Epoch 144/500
# 10/10 [==============================] - 4s 361ms/step - loss: 0.0849 - acc: 0.9667 - val_loss: 0.2245 - val_acc: 0.9500
# Epoch 145/500
# 10/10 [==============================] - 5s 431ms/step - loss: 0.0948 - acc: 0.9567 - val_loss: 0.0891 - val_acc: 0.9750
# Epoch 146/500
# 10/10 [==============================] - 4s 384ms/step - loss: 0.1226 - acc: 0.9500 - val_loss: 0.1768 - val_acc: 0.9500
# Epoch 147/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.0807 - acc: 0.9600 - val_loss: 0.0954 - val_acc: 0.9500
# Epoch 148/500
# 10/10 [==============================] - 4s 363ms/step - loss: 0.1047 - acc: 0.9500 - val_loss: 0.1119 - val_acc: 0.9500
# Epoch 149/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.1294 - acc: 0.9433 - val_loss: 0.1568 - val_acc: 0.9500
# Epoch 150/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.1874 - acc: 0.9167 - val_loss: 0.1102 - val_acc: 0.9250
# Epoch 151/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.1013 - acc: 0.9633 - val_loss: 0.0282 - val_acc: 1.0000
# Epoch 152/500
# 10/10 [==============================] - 5s 506ms/step - loss: 0.1395 - acc: 0.9533 - val_loss: 0.1488 - val_acc: 0.9250
# Epoch 153/500
# 10/10 [==============================] - 5s 458ms/step - loss: 0.1201 - acc: 0.9533 - val_loss: 0.1051 - val_acc: 0.9500
# Epoch 154/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0940 - acc: 0.9667 - val_loss: 0.3493 - val_acc: 0.8750
# Epoch 155/500
# 10/10 [==============================] - 5s 489ms/step - loss: 0.1173 - acc: 0.9500 - val_loss: 0.0379 - val_acc: 1.0000
# Epoch 156/500
# 10/10 [==============================] - 4s 395ms/step - loss: 0.0971 - acc: 0.9633 - val_loss: 0.2036 - val_acc: 0.9250
# Epoch 157/500
# 10/10 [==============================] - 6s 678ms/step - loss: 0.0897 - acc: 0.9633 - val_loss: 0.0953 - val_acc: 0.9750
# Epoch 158/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.0663 - acc: 0.9700 - val_loss: 0.0715 - val_acc: 0.9750
# Epoch 159/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0912 - acc: 0.9700 - val_loss: 0.3174 - val_acc: 0.9250
# Epoch 160/500
# 10/10 [==============================] - 5s 510ms/step - loss: 0.0828 - acc: 0.9700 - val_loss: 0.1975 - val_acc: 0.9000
# Epoch 161/500
# 10/10 [==============================] - 5s 517ms/step - loss: 0.0700 - acc: 0.9767 - val_loss: 0.0541 - val_acc: 0.9750
# Epoch 162/500
# 10/10 [==============================] - 4s 448ms/step - loss: 0.0960 - acc: 0.9667 - val_loss: 0.3854 - val_acc: 0.9000
# Epoch 163/500
# 10/10 [==============================] - 6s 665ms/step - loss: 0.1680 - acc: 0.9500 - val_loss: 0.0833 - val_acc: 0.9750
# Epoch 164/500
# 10/10 [==============================] - 4s 379ms/step - loss: 0.0586 - acc: 0.9800 - val_loss: 0.1144 - val_acc: 0.9750
# Epoch 165/500
# 10/10 [==============================] - 5s 540ms/step - loss: 0.0956 - acc: 0.9567 - val_loss: 0.2452 - val_acc: 0.9250
# Epoch 166/500
# 10/10 [==============================] - 5s 508ms/step - loss: 0.1191 - acc: 0.9367 - val_loss: 0.3447 - val_acc: 0.9000
# Epoch 167/500
# 10/10 [==============================] - 6s 626ms/step - loss: 0.1475 - acc: 0.9533 - val_loss: 0.0228 - val_acc: 1.0000
# Epoch 168/500
# 10/10 [==============================] - 6s 578ms/step - loss: 0.0925 - acc: 0.9633 - val_loss: 0.0522 - val_acc: 0.9750
# Epoch 169/500
# 10/10 [==============================] - 5s 457ms/step - loss: 0.1172 - acc: 0.9500 - val_loss: 0.0357 - val_acc: 0.9750
# Epoch 170/500
# 10/10 [==============================] - 4s 406ms/step - loss: 0.1078 - acc: 0.9533 - val_loss: 0.0368 - val_acc: 1.0000
# Epoch 171/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.1088 - acc: 0.9633 - val_loss: 0.1614 - val_acc: 0.9250
# Epoch 172/500
# 10/10 [==============================] - 5s 534ms/step - loss: 0.1253 - acc: 0.9467 - val_loss: 0.1253 - val_acc: 0.9250
# Epoch 173/500
# 10/10 [==============================] - 5s 497ms/step - loss: 0.0560 - acc: 0.9867 - val_loss: 0.0649 - val_acc: 0.9750
# Epoch 174/500
# 10/10 [==============================] - 5s 466ms/step - loss: 0.1161 - acc: 0.9633 - val_loss: 0.1035 - val_acc: 0.9500
# Epoch 175/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.0937 - acc: 0.9633 - val_loss: 0.0286 - val_acc: 0.9750
# Epoch 176/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.1265 - acc: 0.9533 - val_loss: 0.2150 - val_acc: 0.9250
# Epoch 177/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0586 - acc: 0.9800 - val_loss: 0.1173 - val_acc: 0.9750
# Epoch 178/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0615 - acc: 0.9900 Accurracy is 0.99 then cancel the epoch
# 10/10 [==============================] - 4s 413ms/step - loss: 0.0615 - acc: 0.9900 - val_loss: 0.0971 - val_acc: 0.9750

# %% [markdown]
# ## Plotting Accuracy and Loss graph for Image Model

# %%
def graphsPlot(data_his, str):
  plot.plot(data_his.history[str])
  plot.plot(data_his.history['val_'+str])
  plot.xlabel("Number_of_Epochs")
  plot.ylabel(str)
  plot.legend([str, 'val_'+str])
  plot.show()
  
graphsPlot(data_his, "acc")
graphsPlot(data_his, "loss")

# %% [markdown]
# ## Ploting the Confusion Matrix for Image model

# %%
import seaborn
image_predicted = image_model.predict(validation_generator,20)
predicted_image_labels = image_predicted > 0.5

length = numpy.size(predicted_image_labels)
predicted_image_labels = predicted_image_labels.reshape(length, )

for count in range (1, 5):
  value = count * length // 4
  image_mid = 49
  image_start = image_mid-((value+1)//2)+1
  image_end = image_mid+((value+1)//2)
  confusion_matrix = tf.math.confusion_matrix(labels=validation_generator.labels[image_start:image_end],predictions=predicted_image_labels[image_start:image_end])

  confusion_numpy = confusion_matrix.numpy()
  confidence_accuracy = (confusion_numpy[0, 0] + confusion_numpy[1, 1])/ numpy.sum(confusion_numpy) * 100
  print("Accuracy for", str(value), "Image Data = ", confidence_accuracy)

  plot.figure(figsize = (9,6))
  seaborn.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Blues')
  plot.title("Confusion Matrix for " + str(value) + " Image Data")
  plot.xlabel('Predicted')
  plot.ylabel('Expected')
# Out:
# Accuracy for 25 Image Data =  40.0
# Accuracy for 50 Image Data =  42.857142857142854
# Accuracy for 75 Image Data =  46.666666666666664
# Accuracy for 100 Image Data =  43.43434343434344

# %% [markdown]
# ## Experiment

# %%
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()
result = dict()

for fn in uploaded.keys():
 
  # predicting images
  path = '/content/' + fn
  img = image.load_img(path, target_size=(150, 150))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(classes[0])
  if classes[0]>0.5:
    print(fn + " - Sensitive")
    result[fn] = "Sensitive"
  else:
    print(fn + " - Non-sensitive")
    result[fn] = "Non-sensitive"

plt.figure(figsize=(20,20))
   
for i, fn in enumerate(uploaded.keys()):
  image = plt.imread(fn)  
  plt.subplot(5, 5, i+1)
  plt.axis("off")
  plt.imshow(image)
  ans = fn + ": " + result[fn]
  plt.title(ans)
# Out:
#      <input type="file" id="files-765771d8-a309-4e34-a201-59ece587957d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-765771d8-a309-4e34-a201-59ece587957d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Academic Rep Certificates 2022-Ameer Hussain Nayman.jpg to Academic Rep Certificates 2022-Ameer Hussain Nayman (3).jpg
# Saving COCO_train2014_000000026227.jpg to COCO_train2014_000000026227 (1).jpg
# [1.]
# Academic Rep Certificates 2022-Ameer Hussain Nayman.jpg - Sensitive
# [0.00106932]
# COCO_train2014_000000026227.jpg - Non-sensitive
